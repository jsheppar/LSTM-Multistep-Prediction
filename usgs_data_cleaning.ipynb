# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
#pd.set_option('display.max_columns', None)  # or 1000
#pd.set_option('display.max_rows', None)

# %%
#rain_df = pd.read_csv('./sitka_data/USGS_new/usgs_new_combined.csv', header=4, low_memory=False)

rain_df = pd.read_csv('./sitka_data/USGS_new/cleaned_data/usgs_cleaned_both_pits_3_hour_dt.csv', low_memory=False)

# %%
rain_df
# Out:
#                  Date_Time  Sitka_rain_mm_Tot  Sitka_ec5_vwc_sp1_50cm_mean  \
# 0      2019-09-18 00:00:00                0.0                     0.127571
# 1      2019-09-18 01:00:00                0.0                     0.194083
# 2      2019-09-18 02:00:00                0.0                     0.194750
# 3      2019-09-18 03:00:00                0.0                     0.194333
# 4      2019-09-18 04:00:00                0.0                     0.194000
# ...                    ...                ...                          ...
# 30738  2023-03-21 18:00:00                0.0                     0.222917
# 30739  2023-03-21 19:00:00                0.0                     0.223333
# 30740  2023-03-21 20:00:00                0.0                     0.223583
# 30741  2023-03-21 21:00:00                0.0                     0.223667
# 30742  2023-03-21 22:00:00                0.0                     0.223833
#
# ...

# %%
#rain_df["Date_Time"] = pd.to_datetime(rain_df['Epoch'], unit='s')

rain_df["Date_Time"] = pd.to_datetime(rain_df['Date_Time'])

# %%
# rain_df['Sitka_ec5_vwc_sp1_50cm_max'] = rain_df['Sitka_ec5_vwc_sp1_50cm']
# rain_df['Sitka_ec5_vwc_sp1_25cm_max'] = rain_df['Sitka_ec5_vwc_sp1_25cm']
# rain_df['Sitka_waterPressure_psig_sp1_55cm_max'] = rain_df['Sitka_waterPressure_psig_sp1_55cm']
# rain_df['Sitka_ec5_vwc_sp1_50cm_dt'] = np.pad(np.diff(rain_df['Sitka_ec5_vwc_sp1_50cm'])/5, (0, 1), 'constant')
# rain_df['Sitka_ec5_vwc_sp1_25cm_dt'] = np.pad(np.diff(rain_df['Sitka_ec5_vwc_sp1_25cm'])/5, (0, 1), 'constant')
# rain_df['Sitka_waterPressure_psig_sp1_55cm_dt'] = np.pad(np.diff(rain_df['Sitka_waterPressure_psig_sp1_55cm'].astype('float64'))/5, (0, 1), 'constant')

# rain_df.rename({'Sitka_ec5_vwc_sp1_50cm': 'Sitka_ec5_vwc_sp1_50cm_mean'}, axis='columns', inplace=True)
# rain_df.rename({'Sitka_ec5_vwc_sp1_25cm': 'Sitka_ec5_vwc_sp1_25cm_mean'}, axis='columns', inplace=True)
# rain_df.rename({'Sitka_waterPressure_psig_sp1_55cm': 'Sitka_waterPressure_psig_sp1_55cm_mean'}, axis='columns', inplace=True)


# rain_df['Sitka_ec5_vwc_sp2_40cm_max'] = rain_df['Sitka_ec5_vwc_sp2_40cm']
# rain_df['Sitka_ec5_vwc_sp2_20cm_max'] = rain_df['Sitka_ec5_vwc_sp2_20cm']
# rain_df['Sitka_waterPressure_psig_sp2_60cm_max'] = rain_df['Sitka_waterPressure_psig_sp2_60cm']
# rain_df['Sitka_ec5_vwc_sp2_40cm_dt'] = np.pad(np.diff(rain_df['Sitka_ec5_vwc_sp2_40cm'])/5, (0, 1), 'constant')
# rain_df['Sitka_ec5_vwc_sp2_20cm_dt'] = np.pad(np.diff(rain_df['Sitka_ec5_vwc_sp2_20cm'])/5, (0, 1), 'constant')
# rain_df['Sitka_waterPressure_psig_sp2_60cm_dt'] = np.pad(np.diff(rain_df['Sitka_waterPressure_psig_sp2_60cm'])/5, (0, 1), 'constant')

# rain_df.rename({'Sitka_ec5_vwc_sp2_40cm': 'Sitka_ec5_vwc_sp2_40cm_mean'}, axis='columns', inplace=True)
# rain_df.rename({'Sitka_ec5_vwc_sp2_20cm': 'Sitka_ec5_vwc_sp2_20cm_mean'}, axis='columns', inplace=True)
# rain_df.rename({'Sitka_waterPressure_psig_sp2_60cm': 'Sitka_waterPressure_psig_sp2_60cm_mean'}, axis='columns', inplace=True)

# %%
cleaned_df = rain_df.resample('1H', on="Date_Time").agg({'Sitka_rain_mm_Tot': np.sum,
                                                         'Sitka_ec5_vwc_sp1_50cm_mean': np.mean,
                                                         'Sitka_ec5_vwc_sp1_25cm_mean': np.mean,
                                                         'Sitka_waterPressure_psig_sp1_55cm_mean': np.mean,
                                                         'Sitka_ec5_vwc_sp1_50cm_max': np.max, 
                                                         'Sitka_ec5_vwc_sp1_25cm_max': np.max, 
                                                         'Sitka_waterPressure_psig_sp1_55cm_max': np.max,
                                                         'Sitka_ec5_vwc_sp1_50cm_dt': np.max,
                                                         'Sitka_ec5_vwc_sp1_25cm_dt': np.max,
                                                         'Sitka_waterPressure_psig_sp1_55cm_dt': np.max,
                                                         'Sitka_ec5_vwc_sp2_40cm_mean': np.mean, 
                                                         'Sitka_ec5_vwc_sp2_20cm_mean': np.mean, 
                                                         'Sitka_waterPressure_psig_sp2_60cm_mean': np.mean,
                                                         'Sitka_ec5_vwc_sp2_40cm_max': np.max, 
                                                         'Sitka_ec5_vwc_sp2_20cm_max': np.max, 
                                                         'Sitka_waterPressure_psig_sp2_60cm_max': np.max,
                                                         'Sitka_ec5_vwc_sp2_40cm_dt': np.max,
                                                         'Sitka_ec5_vwc_sp2_20cm_dt': np.max,
                                                         'Sitka_waterPressure_psig_sp2_60cm_dt': np.max
                                                        })

# cleaned_df = rain_df.resample('3H', on="Date_Time", origin='start_day').agg({'Sitka_rain_mm_Tot': np.sum,
#                                                                               'Sitka_ec5_vwc_sp1_50cm_mean': np.mean, 
#                                                          'Sitka_ec5_vwc_sp1_25cm_mean': np.mean, 
#                                                          'Sitka_waterPressure_psig_sp1_55cm_mean': np.mean,
#                                                          'Sitka_ec5_vwc_sp1_50cm_max': np.max, 
#                                                          'Sitka_ec5_vwc_sp1_25cm_max': np.max, 
#                                                          'Sitka_waterPressure_psig_sp1_55cm_max': np.max,
#                                                          'Sitka_ec5_vwc_sp1_50cm_dt': np.max,
#                                                          'Sitka_ec5_vwc_sp1_25cm_dt': np.max,
#                                                          'Sitka_waterPressure_psig_sp1_55cm_dt': np.max,
#                                                          'Sitka_ec5_vwc_sp2_40cm_mean': np.mean, 
#                                                          'Sitka_ec5_vwc_sp2_20cm_mean': np.mean, 
#                                                          'Sitka_waterPressure_psig_sp2_60cm_mean': np.mean,
#                                                          'Sitka_ec5_vwc_sp2_40cm_max': np.max, 
#                                                          'Sitka_ec5_vwc_sp2_20cm_max': np.max, 
#                                                          'Sitka_waterPressure_psig_sp2_60cm_max': np.max,
#                                                          'Sitka_ec5_vwc_sp2_40cm_dt': np.max,
#                                                          'Sitka_ec5_vwc_sp2_20cm_dt': np.max,
#                                                          'Sitka_waterPressure_psig_sp2_60cm_dt': np.max
#                                                        })

cleaned_df.dropna(subset=['Sitka_rain_mm_Tot'], inplace=True)

# %%
cleaned_df
# Out:
#                      Sitka_rain_mm_Tot  Sitka_ec5_vwc_sp1_50cm_mean  \
# Date_Time
# 2019-09-18 00:00:00                0.0                     0.172135
# 2019-09-18 03:00:00                0.0                     0.194111
# 2019-09-18 06:00:00                0.0                     0.194056
# 2019-09-18 09:00:00                0.0                     0.194000
# 2019-09-18 12:00:00                0.0                     0.194556
# ...                                ...                          ...
# 2023-03-21 09:00:00                0.0                     0.224028
# 2023-03-21 12:00:00                0.0                     0.223722
# 2023-03-21 15:00:00                0.0                     0.223083
# 2023-03-21 18:00:00                0.0                     0.223278
# 2023-03-21 21:00:00                0.0                     0.223750
#
#                      Sitka_ec5_vwc_sp1_25cm_mean  \
# Date_Time
# 2019-09-18 00:00:00                     0.110575
# ...

# %%
cleaned_df.to_csv('./sitka_data/USGS_new/cleaned_data/usgs_cleaned_both_pits_3_hour_dt_redo.csv', date_format='%Y-%m-%d %H:%M:%S')
