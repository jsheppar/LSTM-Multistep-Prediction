# %%
# %load_ext autoreload
# %autoreload 2

# %%
#everything we will import to use later
import os
import numpy as np
import pandas as pd
from datetime import datetime, date, timedelta
from matplotlib import pyplot as plt
from functions import add_max_rainfall
import tqdm
from tqdm.notebook import tqdm_notebook

# %%
airport_df = pd.read_csv('./sitka_data/Airport_new/cleaned_data/airport_cleaned_3_hour_wind.csv')#, index_col='Date_Time')
usgs_df = pd.read_csv('./sitka_data/USGS_new/cleaned_data/usgs_cleaned_3_hour_dt.csv')#, index_col='Date_Time')
airport_df["Date_Time"] = pd.to_datetime(airport_df["Date_Time"])
usgs_df["Date_Time"] = pd.to_datetime(usgs_df["Date_Time"])
usgs_df = usgs_df[usgs_df["Date_Time"]>="2020-06-09 21:00:00"]
combined_df = airport_df.merge(usgs_df, on="Date_Time", how="left")
combined_df.set_index("Date_Time", inplace=True, drop=True)

# %%
combined_df.iloc[-30:]
# Out:
#                      wind_speed_meter_sec  wind_direction_x  wind_direction_y  \
# Date_Time
# 2023-03-20 18:00:00                   NaN               NaN               NaN
# 2023-03-20 21:00:00                   NaN               NaN               NaN
# 2023-03-21 00:00:00                   NaN               NaN               NaN
# 2023-03-21 03:00:00                   NaN               NaN               NaN
# 2023-03-21 06:00:00                   NaN               NaN               NaN
# 2023-03-21 09:00:00                   NaN               NaN               NaN
# 2023-03-21 12:00:00                   NaN               NaN               NaN
# 2023-03-21 15:00:00                   NaN               NaN               NaN
# 2023-03-21 18:00:00                   NaN               NaN               NaN
# 2023-03-21 21:00:00                   NaN               NaN               NaN
# 2023-03-22 00:00:00              3.326071          0.622408         -0.515685
# 2023-03-22 03:00:00              3.922263          0.917361         -0.369540
# 2023-03-22 06:00:00              3.998462          0.879137         -0.476569
# 2023-03-22 09:00:00              4.984359          0.868766         -0.491290
# 2023-03-22 12:00:00              5.537692          0.885456         -0.464723
# 2023-03-22 15:00:00                   NaN               NaN               NaN
# 2023-03-22 18:00:00              6.905385          0.910893         -0.409960
# 2023-03-22 21:00:00              8.033077          0.885456         -0.464723
# 2023-03-23 00:00:00              7.373846          0.845038         -0.534369
# 2023-03-23 03:00:00                   NaN               NaN               NaN
# 2023-03-23 06:00:00                   NaN               NaN               NaN
# 2023-03-23 09:00:00              4.116154          0.993852         -0.004289
# 2023-03-23 12:00:00              1.939231          0.837939          0.545765
# 2023-03-23 15:00:00              4.472125          0.216701         -0.652307
# 2023-03-23 18:00:00              2.690769          0.727891         -0.594304
# 2023-03-23 21:00:00              1.293413          0.999048          0.000000
# 2023-03-24 00:00:00                   NaN               NaN               NaN
# 2023-03-24 03:00:00                   NaN               NaN               NaN
# 2023-03-24 06:00:00                   NaN               NaN               NaN
# 2023-03-24 09:00:00              3.308635          0.889758         -0.442968
#
#                      precip_accum_one_hour_mm  Sitka_rain_mm_Tot  \
# Date_Time
# 2023-03-20 18:00:00                     0.000                0.2
# 2023-03-20 21:00:00                     0.000                0.0
# 2023-03-21 00:00:00                     0.000                0.0
# 2023-03-21 03:00:00                     0.000                0.0
# 2023-03-21 06:00:00                     0.000                0.0
# 2023-03-21 09:00:00                     0.000                0.0
# 2023-03-21 12:00:00                     0.000                0.0
# 2023-03-21 15:00:00                     0.000                0.0
# 2023-03-21 18:00:00                     0.000                0.0
# 2023-03-23 21:00:00                                   NaN
# 2023-03-24 00:00:00                                   NaN
# 2023-03-24 03:00:00                                   NaN
# 2023-03-24 06:00:00                                   NaN
# 2023-03-24 09:00:00                                   NaN

# %%
combined_df.to_csv('./sitka_data/combined_3_hour_wind.csv', columns=["wind_speed_meter_sec", 
                                                                    "wind_direction_x", "wind_direction_y", 
                                                                    "precip_accum_one_hour_mm", "Sitka_ec5_vwc_sp2_40cm_mean", 
                                                                    "Sitka_ec5_vwc_sp2_20cm_mean", "Sitka_waterPressure_psig_sp2_60cm_mean", 
                                                                    "Sitka_ec5_vwc_sp2_40cm_max", "Sitka_ec5_vwc_sp2_20cm_max",	
                                                                    "Sitka_waterPressure_psig_sp2_60cm_max", "Sitka_ec5_vwc_sp2_40cm_dt", "Sitka_ec5_vwc_sp2_20cm_dt", 
                                                                    "Sitka_waterPressure_psig_sp2_60cm_dt"], date_format='%Y-%m-%d %H:%M:%S')

# %%
ocr = pd.read_csv('./sitka_data/combined_hourly_wind.csv', index_col='Date_Time')#,sep='\t')

ocr.index = pd.to_datetime(ocr.index)

pp_cols = [v for v in ocr.columns if "Pressure_" in v]  # allows any pp depths, as the depth varies from pit to pit
VWC_cols = [v for v in ocr.columns if "vwc_" in v]  # allows any water content depths, as the depth varies from pit to pit
ocr[pp_cols] = ocr[pp_cols].mask(ocr[pp_cols] < -14) #mask pp smaller than -14, we're interested in larger pp

# add in forecasted rainfall
for i in tqdm_notebook(range(1,37,1)):
    ocr = add_max_rainfall(ocr, i, 0, noise=False)
    
#df.sort_index(axis=1, inplace=True) 
    
cols_at_end = VWC_cols + pp_cols
ocr = ocr[[c for c in ocr if c not in cols_at_end] + [c for c in cols_at_end if c in ocr]]

ocr.to_csv('./sitka_data/processed_for_training_hourly.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [10], in <cell line: 10>()
#       7 ocr[pp_cols] = ocr[pp_cols].mask(ocr[pp_cols] < -14) #mask pp smaller than -14, we're interested in larger pp
#       9 # add in forecasted rainfall
# ---> 10 for i in tqdm_notebook(range(1,37,1)):
#      11     ocr = add_max_rainfall(ocr, i, 0, noise=False)
#      13 #df.sort_index(axis=1, inplace=True)
#
# File ~/Dropbox (University of Oregon)/GitHub/LSTM-Multistep-Prediction/env/lib/python3.9/site-packages/tqdm/notebook.py:242, in tqdm_notebook.__init__(self, *args, **kwargs)
#     240 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241 total = self.total * unit_scale if self.total else self.total
# --> 242 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243 self.container.pbar = proxy(self)
#     244 self.displayed = False
#
# File ~/Dropbox (University of Oregon)/GitHub/LSTM-Multistep-Prediction/env/lib/python3.9/site-packages/tqdm/notebook.py:115, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     106 # Fallback to text bar if there's no total
#     107 # DEPRECATED: replaced with an 'info' style bar
#     108 # if not total:
#    (...)
#     112
#     113 # Prepare IPython progress bar
#     114 if IProgress is None:  # #187 #451 #558 #872
# --> 115     raise ImportError(
#     116         "IProgress not found. Please update jupyter and ipywidgets."
#     117         " See https://ipywidgets.readthedocs.io/en/stable"
#     118         "/user_install.html")
#     119 if total:
#     120     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
