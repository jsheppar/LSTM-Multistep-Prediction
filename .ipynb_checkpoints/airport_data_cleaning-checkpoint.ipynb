# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
rain_df = pd.read_csv('./sitka_data/Airport_new/airport_new_wind.csv', header=10, low_memory=False)

#rain_df = pd.read_csv('./sitka_data/Airport_new/cleaned_data/airport_cleaned_hourly.csv', low_memory=False)

# %%
rain_df
# Out:
#        Station_ID             Date_Time  wind_speed_meter_sec  \
# 0            PASI  2002-11-05T20:50:00Z                  6.17
# 1            PASI  2002-11-05T21:50:00Z                  6.17
# 2            PASI  2002-11-05T22:50:00Z                  7.20
# 3            PASI  2002-11-05T23:50:00Z                  6.17
# 4            PASI  2002-11-06T00:50:00Z                  7.72
# ...           ...                   ...                   ...
# 853061       PASI  2023-03-24T11:45:00Z                  3.09
# 853062       PASI  2023-03-24T11:50:00Z                  2.57
# 853063       PASI  2023-03-24T11:53:00Z                  2.57
# 853064       PASI  2023-03-24T11:55:00Z                  2.57
# 853065       PASI  2023-03-24T12:00:00Z                  2.57
#
#         wind_direction_degree  wind_gust_meter_sec  precip_accum_one_hour_mm  \
# 0                       100.0                  NaN                       NaN
# 1                       120.0                  NaN                       NaN
# 2                       120.0                11.83                       NaN
# 3                       110.0                  NaN                       NaN
# 4                        90.0                10.29                       NaN
# ...                       ...                  ...                       ...
# 853061                  170.0                  NaN                       NaN
# 853062                  120.0                  NaN                       NaN
# 853063                  110.0                  NaN                     0.254
# 853064                  100.0                  NaN                       NaN
# 853065                  100.0                  NaN                       NaN
#
#         peak_wind_speed_meter_sec  peak_wind_direction_degree  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 853061                        NaN                         NaN
# 853062                        NaN                         NaN
# 853063                        NaN                         NaN
# 853064                        NaN                         NaN
# 853065                        NaN                         NaN
#
#        wind_cardinal_direction
# 0                            E
# 1                          ESE
# 2                          ESE
# 3                          ESE
# 4                            E
# ...                        ...
# 853061                       S
# 853062                     ESE
# 853063                     ESE
# 853064                       E
# 853065                       E
#
# [853066 rows x 9 columns]

# %%
rain_df["Date_Time"] = pd.to_datetime(rain_df["Date_Time"])

# rain_df.loc[rain_df['UTC_TIME']==0,'UTC_TIME'] = '0000'
# rain_df['Date_Time'] = rain_df['UTC_DATE'].astype(str) + ' ' + rain_df['UTC_TIME'].astype(str)
# rain_df['Date_Time'] = pd.to_datetime(rain_df["Date_Time"], utc=True, format='%Y%m%d %H%M')

# %%
# modulo
#rain_df = rain_df[(rain_df["precip_accum_one_hour_mm"]*1000)%(0.254*1000) == 0]

# %%
rain_df['wind_direction_x'] = rain_df['wind_direction_degree']
rain_df['wind_direction_y'] = rain_df['wind_direction_degree']

# %%
cleaned_df = rain_df.resample('1H', on="Date_Time").agg({'precip_accum_one_hour_mm': np.max, 
                                                         'wind_speed_meter_sec': np.mean, 
                                                         'wind_direction_degree': np.mean,
                                                         'wind_direction_x': np.mean,
                                                         'wind_direction_y': np.mean
                                                        })

# cleaned_df = rain_df.resample('24H', on="Date_Time", origin='start_day').agg({'precip_accum_one_hour_mm': np.sum, 
#                                                          'wind_speed_meter_sec': np.mean, 
#                                                          'wind_direction_degree': np.mean})


cleaned_df.dropna(subset=['precip_accum_one_hour_mm'], inplace=True)

# %%
cleaned_df.loc[cleaned_df['wind_direction_degree'] <= 90, 'wind_direction_x'] = np.cos(np.radians(90-cleaned_df['wind_direction_degree']))
cleaned_df.loc[cleaned_df['wind_direction_degree'] <= 90, 'wind_direction_y'] = np.sin(np.radians(90-cleaned_df['wind_direction_degree']))

cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 90) & 
             (cleaned_df['wind_direction_degree'] <= 180), 'wind_direction_x'] = np.sin(np.radians(180-cleaned_df['wind_direction_degree']))
cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 90) & 
             (cleaned_df['wind_direction_degree'] <= 180), 'wind_direction_y'] = -np.cos(np.radians(180-cleaned_df['wind_direction_degree']))

cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 180) & 
             (cleaned_df['wind_direction_degree'] <= 270), 'wind_direction_x'] = -np.cos(np.radians(270-cleaned_df['wind_direction_degree']))
cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 180) & 
             (cleaned_df['wind_direction_degree'] <= 270), 'wind_direction_y'] = -np.sin(np.radians(270-cleaned_df['wind_direction_degree']))

cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 270) & 
             (cleaned_df['wind_direction_degree'] <= 360), 'wind_direction_x'] = -np.sin(np.radians(360-cleaned_df['wind_direction_degree']))
cleaned_df.loc[(cleaned_df['wind_direction_degree'] > 270) & 
             (cleaned_df['wind_direction_degree'] <= 360), 'wind_direction_y'] = np.cos(np.radians(360-cleaned_df['wind_direction_degree']))

# %%
cleaned_df
# Out:
#                            precip_accum_one_hour_mm  wind_speed_meter_sec  \
# Date_Time
# 2002-11-06 08:00:00+00:00                     0.000              6.690000
# 2002-11-06 09:00:00+00:00                     0.000              9.770000
# 2002-11-06 12:00:00+00:00                     0.000              8.750000
# 2002-11-06 13:00:00+00:00                     0.254              8.230000
# 2002-11-06 14:00:00+00:00                     2.794              9.600000
# ...                                             ...                   ...
# 2023-03-23 21:00:00+00:00                     0.508              1.463077
# 2023-03-23 22:00:00+00:00                     0.025              1.123750
# 2023-03-24 09:00:00+00:00                     0.025              3.602857
# 2023-03-24 10:00:00+00:00                     0.025              3.567333
# 2023-03-24 11:00:00+00:00                     0.254              2.755714
#
#                            wind_direction_degree  wind_direction_x  \
# Date_Time
# 2002-11-06 08:00:00+00:00             100.000000          0.984808
# 2002-11-06 09:00:00+00:00             110.000000          0.939693
# 2002-11-06 12:00:00+00:00             120.000000          0.866025
# 2002-11-06 13:00:00+00:00             120.000000          0.866025
# 2002-11-06 14:00:00+00:00             163.333333          0.286803
# ...                                          ...               ...
# 2023-03-23 21:00:00+00:00              87.500000          0.999048
# 2023-03-23 22:00:00+00:00              92.500000          0.999048
# 2023-03-24 09:00:00+00:00             122.857143          0.840026
# 2023-03-24 10:00:00+00:00             118.666667          0.877425
# 2023-03-24 11:00:00+00:00             107.857143          0.951824
#
#                            wind_direction_y
# Date_Time
# 2002-11-06 08:00:00+00:00         -0.173648
# 2002-11-06 09:00:00+00:00         -0.342020
# 2002-11-06 12:00:00+00:00         -0.500000
# 2002-11-06 13:00:00+00:00         -0.500000
# 2002-11-06 14:00:00+00:00         -0.957990
# ...                                     ...
# 2023-03-23 21:00:00+00:00          0.043619
# 2023-03-23 22:00:00+00:00         -0.043619
# 2023-03-24 09:00:00+00:00         -0.542546
# 2023-03-24 10:00:00+00:00         -0.479713
# 2023-03-24 11:00:00+00:00         -0.306645
#
# [68463 rows x 5 columns]

# %%
cleaned_df.to_csv('./sitka_data/Airport_new/cleaned_data/airport_cleaned_24_hour_mod.csv', columns=["wind_speed_meter_sec", 
                                                                                                    "wind_direction_degree", 
                                                                                                    "precip_accum_one_hour_mm"], date_format='%Y-%m-%d %H:%M:%S')



#cleaned_df.to_csv('./sitka_data/USCRN_new/cleaned_data/uscrn_cleaned_3_hour.csv', columns=["P_CALC"], date_format='%Y-%m-%d %H:%M:%S')
